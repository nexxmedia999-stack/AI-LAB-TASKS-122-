# %%
print("=== Jolt-Rumble-Strum Game (1-50) ===")

for number in range(1, 51):
    if number % 4 == 0 and number % 7 == 0:
        print("Jolt-Rumble-Strum")
    elif number % 4 == 0:
        print("Jolt")
    elif number % 7 == 0:
        print("Rumble")
    else:
        print(number)
# Out:
# === Jolt-Rumble-Strum Game (1-50) ===
# 1
# 2
# 3
# Jolt
# 5
# 6
# Rumble
# Jolt
# 9
# 10
# 11
# Jolt
# 13
# Rumble
# 15
# Jolt
# 17
# 18
# 19
# Jolt
# Rumble
# 22
# 23
# Jolt
# 25
# 26
# 27
# Jolt-Rumble-Strum
# 29
# 30
# 31
# Jolt
# 33
# 34
# Rumble
# Jolt
# 37
# 38
# 39
# Jolt
# 41
# Rumble
# 43
# Jolt
# 45
# 46
# 47
# Jolt
# Rumble
# 50
